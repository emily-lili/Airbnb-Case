# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
listings = air_bnb.groupby('neighbourhood_group', as_index = False).count()[['neighbourhood_group','id']].sort_values(by = 'id', ascending = False).reset_index(drop = True)
listings
# Out:
#   neighbourhood_group     id
# 0           Manhattan  21661
# 1            Brooklyn  20104
# 2              Queens   5666
# 3               Bronx   1091
# 4       Staten Island    373

# %%
# Are private rooms the most popular in manhattan?
air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan'].groupby('room_type', as_index = False).count()[['room_type', 'id']].sort_values(by = 'id', ascending = False)
# Out:
#          room_type     id
# 0  Entire home/apt  13199
# 1     Private room   7982
# 2      Shared room    480

# %%
# Which hosts are the busiest and based on their reviews?
hosts = pd.DataFrame.from_dict({
    'Host Name': air_bnb['host_name'],
    'Host ID': air_bnb['host_id'],
    'Reviews': air_bnb['number_of_reviews']
})
hosts = air_bnb_hosts.groupby(['Host ID', 'Host Name']).sum(['Reviews']).sort_values(by=['Reviews'], ascending=False)
hosts
# Out:
#                                           Reviews
# Host ID   Host Name
# 37312959  Maya                               2273
# 344035    Brooklyn&   Breakfast    -Len-     2205
# 26432133  Danielle                           2017
# 35524316  Yasu & Akiko                       1971
# 40176101  Brady                              1818
# ...                                           ...
# 39695769  Avra                                  0
# 39706334  Erin                                  0
# 39724060  Jaime                                 0
# 39731713  Polina                                0
# 274321313 Kat                                   0
#
# [37439 rows x 1 columns]

# %%
#Which neighorhood group has the highest average price?
air_bnb_price = pd.DataFrame.from_dict({
    "Neighbourhood Group": air_bnb['neighbourhood_group'],
    "Price": air_bnb['price']
})
air_bnb_price = air_bnb_price.groupby(['Neighbourhood Group']).mean(['Price']).sort_values(by=['Price'],ascending = False)
air_bnb_price
# Out:
#                           Price
# Neighbourhood Group
# Manhattan            196.875814
# Brooklyn             124.383207
# Staten Island        114.812332
# Queens                99.517649
# Bronx                 87.496792

# %%
# Which neighbor hood group has the highest total price?
sum_price = air_bnb.groupby('neighbourhood_group', as_index = False).sum()[['neighbourhood_group','price']].sort_values(by = 'price', ascending = False).reset_index(drop = True)
sum_price
# Out:
#   neighbourhood_group    price
# 0           Manhattan  4264527
# 1            Brooklyn  2500600
# 2              Queens   563867
# 3               Bronx    95459
# 4       Staten Island    42825

# %%
#Which top 5 hosts have the highest total price?
air_bnb_total = air_bnb[['host_id', 'host_name', 'neighbourhood_group', 'price']]
air_bnb_total = air_bnb_total.groupby(['host_id', 'host_name', 'neighbourhood_group']).sum(['price']).sort_values(by=['price'], ascending=False)
air_bnb_total
# Out:
#                                             price
# host_id   host_name    neighbourhood_group
# 219517861 Sonder (NYC) Manhattan            82795
# 107434423 Blueground   Manhattan            69741
# 205031545 Red Awning   Manhattan            35294
# 30283594  Kara         Manhattan            33581
# 156158778 Sally        Manhattan            29194
# ...                                           ...
# 91034542  Maureen      Manhattan               10
# 205820814 Luz          Bronx                   10
# 52777892  Amy          Manhattan               10
# 10132166  Aymeric      Brooklyn                 0
# 13709292  Qiuchi       Manhattan                0
#
# [37554 rows x 1 columns]

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
#idk

# %%
# What host has the highest total of prices and where are they located?

#idk

# %%
# When did Danielle from Queens last receive a review?
air_bnb[(air_bnb['host_name'] == "Danielle") & (air_bnb['neighbourhood_group'] ==  "Queens")]
# Out:
#              id                                               name    host_id  \
# 7086    5115372  Comfy Room Family Home LGA Airport NO CLEANING...   26432133
# 16349  13151075                    ASTORIA APARTMENT OUTDOOR SPACE   18051286
# 20403  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE   26432133
# 21517  17222454   Sun Room Family Home LGA Airport NO CLEANING FEE   26432133
# 22068  17754072                Bed in Family Home Near LGA Airport   26432133
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE   26432133
# 27021  21386105  Quiet & clean 1br haven with balcony near the ...  154256662
# 33861  26814763  One bedroom with full bed / 1 stop from Manhattan  201647469
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 7086   Danielle              Queens     East Elmhurst  40.76374  -73.87103
# 16349  Danielle              Queens           Astoria  40.77221  -73.92901
# ...

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#IDK

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
air_bnb[air_bnb['availability_365']==365]
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 38        11943                          Country space in the city      45445
# 97        21644                          Upper Manhattan, New York      82685
# ...         ...                                                ...        ...
# 48744  36415840         A BEAUTIFUL SPACE IN HEART OF WILLIAMSBURG  223715460
# 48844  36453952    West Village Studio on quiet cobblestone street  115491896
# 48868  36473253                       Heaven for you(only for guy)  261338177
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
#
# ...

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
air_bnb.groupby('room_type', as_index = False).count()[['room_type', 'id']].sort_values(by = 'id', ascending = False)
# Out:
#          room_type     id
# 0  Entire home/apt  25409
# 1     Private room  22326
# 2      Shared room   1160

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
